# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d66c44fd-c661-4397-be27-7a4b21d0189c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d66c44fd-c661-4397-be27-7a4b21d0189c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv('netflix_viewership_dataset.csv')

# %%
df=pd.DataFrame(df)
df
# Out:
#           Date     Region       Movie Title     Genre  Views (millions)  \
# 0   2025-09-06      India     Don't Look Up     Drama              1.88
# 1   2025-09-29  Australia      Extraction 2  Thriller             12.51
# 2   2025-09-28      India     Project Power     Drama             10.47
# 3   2025-09-24         UK  The Adam Project    Horror              7.35
# 4   2025-09-09  Australia     The Old Guard  Thriller              2.22
# ..         ...        ...               ...       ...               ...
# 95  2025-09-23  Australia     The Old Guard    Comedy              6.94
# 96  2025-09-04     Canada     The Old Guard    Action             10.22
# 97  2025-09-20     Canada       Glass Onion    Action             14.90
# 98  2025-09-14         UK  The Adam Project     Drama             14.94
# 99  2025-09-30    Germany  The Adam Project   Romance              8.24
#
#     Watch Time (hours)  Revenue (USD millions) Subscriber Type
# ...

# %%
df.head()
# Out:
#          Date     Region       Movie Title     Genre  Views (millions)  \
# 0  2025-09-06      India     Don't Look Up     Drama              1.88
# 1  2025-09-29  Australia      Extraction 2  Thriller             12.51
# 2  2025-09-28      India     Project Power     Drama             10.47
# 3  2025-09-24         UK  The Adam Project    Horror              7.35
# 4  2025-09-09  Australia     The Old Guard  Thriller              2.22
#
#    Watch Time (hours)  Revenue (USD millions) Subscriber Type
# 0                4.58                    3.11        Standard
# 1               21.21                   13.72        Standard
# 2               29.51                   16.69        Standard
# 3               19.89                    6.83        Standard
# 4                6.69                    3.49         Premium

# %%
df.tail()
# Out:
#           Date     Region       Movie Title    Genre  Views (millions)  \
# 95  2025-09-23  Australia     The Old Guard   Comedy              6.94
# 96  2025-09-04     Canada     The Old Guard   Action             10.22
# 97  2025-09-20     Canada       Glass Onion   Action             14.90
# 98  2025-09-14         UK  The Adam Project    Drama             14.94
# 99  2025-09-30    Germany  The Adam Project  Romance              8.24
#
#     Watch Time (hours)  Revenue (USD millions) Subscriber Type
# 95               23.83                    5.93        Standard
# 96               25.76                    9.02         Premium
# 97               34.36                   18.60           Basic
# 98               49.58                   21.41        Standard
# 99               14.26                   13.10           Basic

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    100 non-null    object
#  1   Region                  100 non-null    object
#  2   Movie Title             100 non-null    object
#  3   Genre                   100 non-null    object
#  4   Views (millions)        100 non-null    float64
#  5   Watch Time (hours)      100 non-null    float64
#  6   Revenue (USD millions)  100 non-null    float64
#  7   Subscriber Type         100 non-null    object
# dtypes: float64(3), object(5)
# memory usage: 6.4+ KB

# %%
df.describe()
# Out:
#        Views (millions)  Watch Time (hours)  Revenue (USD millions)
# count        100.000000          100.000000              100.000000
# mean           7.486500           19.815300                9.982100
# std            4.196995           12.333859                6.458924
# min            0.600000            1.180000                0.920000
# 25%            4.310000            9.950000                4.895000
# 50%            7.220000           17.220000                8.395000
# 75%           10.582500           27.832500               14.512500
# max           15.000000           49.830000               27.800000

# %%
df.shape
# Out:
# (100, 8)

# %%
df.columns
# Out:
# Index(['Date', 'Region', 'Movie Title', 'Genre', 'Views (millions)',
#        'Watch Time (hours)', 'Revenue (USD millions)', 'Subscriber Type'],
#       dtype='object')

# %%
df.values
# Out:
# array([['2025-09-06', 'India', "Don't Look Up", 'Drama', 1.88, 4.58,
#         3.11, 'Standard'],
#        ['2025-09-29', 'Australia', 'Extraction 2', 'Thriller', 12.51,
#         21.21, 13.72, 'Standard'],
#        ['2025-09-28', 'India', 'Project Power', 'Drama', 10.47, 29.51,
#         16.69, 'Standard'],
#        ['2025-09-24', 'UK', 'The Adam Project', 'Horror', 7.35, 19.89,
#         6.83, 'Standard'],
#        ['2025-09-09', 'Australia', 'The Old Guard', 'Thriller', 2.22,
#         6.69, 3.49, 'Premium'],
#        ['2025-09-30', 'Germany', 'Red Notice', 'Romance', 9.16, 17.72,
#         15.82, 'Basic'],
#        ['2025-09-23', 'Australia', 'Army of the Dead', 'Drama', 5.15,
#         13.62, 8.19, 'Basic'],
#        ['2025-09-20', 'Japan', 'The Gray Man', 'Horror', 4.71, 12.8,
#         7.72, 'Standard'],
#        ['2025-09-23', 'USA', 'The Adam Project', 'Thriller', 4.32, 9.6,
#         4.56, 'Premium'],
# ...

# %%
df.dtypes
# Out:
# Date                       object
# Region                     object
# Movie Title                object
# Genre                      object
# Views (millions)          float64
# Watch Time (hours)        float64
# Revenue (USD millions)    float64
# Subscriber Type            object
# dtype: object

# %%
df.loc[0]
# Out:
# Date                         2025-09-06
# Region                            India
# Movie Title               Don't Look Up
# Genre                             Drama
# Views (millions)                   1.88
# Watch Time (hours)                 4.58
# Revenue (USD millions)             3.11
# Subscriber Type                Standard
# Name: 0, dtype: object

# %%
df_dropped=df.drop(columns=['Revenue (USD millions)'])
df_dropped
# Out:
#           Date     Region       Movie Title     Genre  Views (millions)  \
# 0   2025-09-06      India     Don't Look Up     Drama              1.88
# 1   2025-09-29  Australia      Extraction 2  Thriller             12.51
# 2   2025-09-28      India     Project Power     Drama             10.47
# 3   2025-09-24         UK  The Adam Project    Horror              7.35
# 4   2025-09-09  Australia     The Old Guard  Thriller              2.22
# ..         ...        ...               ...       ...               ...
# 95  2025-09-23  Australia     The Old Guard    Comedy              6.94
# 96  2025-09-04     Canada     The Old Guard    Action             10.22
# 97  2025-09-20     Canada       Glass Onion    Action             14.90
# 98  2025-09-14         UK  The Adam Project     Drama             14.94
# 99  2025-09-30    Germany  The Adam Project   Romance              8.24
#
#     Watch Time (hours) Subscriber Type
# 0                 4.58        Standard
# ...

# %%
df_renamed = df.rename(columns={'Movie Title': 'Movie'})
df_renamed
# Out:
#           Date     Region             Movie     Genre  Views (millions)  \
# 0   2025-09-06      India     Don't Look Up     Drama              1.88
# 1   2025-09-29  Australia      Extraction 2  Thriller             12.51
# 2   2025-09-28      India     Project Power     Drama             10.47
# 3   2025-09-24         UK  The Adam Project    Horror              7.35
# 4   2025-09-09  Australia     The Old Guard  Thriller              2.22
# ..         ...        ...               ...       ...               ...
# 95  2025-09-23  Australia     The Old Guard    Comedy              6.94
# 96  2025-09-04     Canada     The Old Guard    Action             10.22
# 97  2025-09-20     Canada       Glass Onion    Action             14.90
# 98  2025-09-14         UK  The Adam Project     Drama             14.94
# 99  2025-09-30    Germany  The Adam Project   Romance              8.24
#
#     Watch Time (hours)  Revenue (USD millions) Subscriber Type
# ...

# %%
df_sorted = df.sort_values(by='Views (millions)')
df_sorted
# Out:
#           Date   Region       Movie Title     Genre  Views (millions)  \
# 85  2025-09-24       UK     Don't Look Up    Comedy              0.60
# 37  2025-09-19   Canada      Extraction 2    Action              0.67
# 76  2025-09-29   Brazil      The Gray Man  Thriller              0.79
# 14  2025-09-21  Germany   Triple Frontier    Horror              0.89
# 72  2025-09-18       UK    Enola Holmes 2   Romance              1.22
# ..         ...      ...               ...       ...               ...
# 65  2025-09-17      USA     The Old Guard    Comedy             14.82
# 79  2025-09-15   Canada    Enola Holmes 2     Drama             14.83
# 97  2025-09-20   Canada       Glass Onion    Action             14.90
# 98  2025-09-14       UK  The Adam Project     Drama             14.94
# 33  2025-09-11    Japan        The Mother  Thriller             15.00
#
#     Watch Time (hours)  Revenue (USD millions) Subscriber Type
# 85                2.05                    0.92         Premium
# ...

# %%
df_filled = df.fillna(0)
df_filled
# Out:
#           Date     Region       Movie Title     Genre  Views (millions)  \
# 0   2025-09-06      India     Don't Look Up     Drama              1.88
# 1   2025-09-29  Australia      Extraction 2  Thriller             12.51
# 2   2025-09-28      India     Project Power     Drama             10.47
# 3   2025-09-24         UK  The Adam Project    Horror              7.35
# 4   2025-09-09  Australia     The Old Guard  Thriller              2.22
# ..         ...        ...               ...       ...               ...
# 95  2025-09-23  Australia     The Old Guard    Comedy              6.94
# 96  2025-09-04     Canada     The Old Guard    Action             10.22
# 97  2025-09-20     Canada       Glass Onion    Action             14.90
# 98  2025-09-14         UK  The Adam Project     Drama             14.94
# 99  2025-09-30    Germany  The Adam Project   Romance              8.24
#
#     Watch Time (hours)  Revenue (USD millions) Subscriber Type
# ...

# %%
df_unique = df.drop_duplicates()
df_unique
# Out:
#           Date     Region       Movie Title     Genre  Views (millions)  \
# 0   2025-09-06      India     Don't Look Up     Drama              1.88
# 1   2025-09-29  Australia      Extraction 2  Thriller             12.51
# 2   2025-09-28      India     Project Power     Drama             10.47
# 3   2025-09-24         UK  The Adam Project    Horror              7.35
# 4   2025-09-09  Australia     The Old Guard  Thriller              2.22
# ..         ...        ...               ...       ...               ...
# 95  2025-09-23  Australia     The Old Guard    Comedy              6.94
# 96  2025-09-04     Canada     The Old Guard    Action             10.22
# 97  2025-09-20     Canada       Glass Onion    Action             14.90
# 98  2025-09-14         UK  The Adam Project     Drama             14.94
# 99  2025-09-30    Germany  The Adam Project   Romance              8.24
#
#     Watch Time (hours)  Revenue (USD millions) Subscriber Type
# ...

# %%
df_replaced = df.replace({'Project Power': 'Power puff'})
df_replaced
# Out:
#           Date     Region       Movie Title     Genre  Views (millions)  \
# 0   2025-09-06      India     Don't Look Up     Drama              1.88
# 1   2025-09-29  Australia      Extraction 2  Thriller             12.51
# 2   2025-09-28      India        Power puff     Drama             10.47
# 3   2025-09-24         UK  The Adam Project    Horror              7.35
# 4   2025-09-09  Australia     The Old Guard  Thriller              2.22
# ..         ...        ...               ...       ...               ...
# 95  2025-09-23  Australia     The Old Guard    Comedy              6.94
# 96  2025-09-04     Canada     The Old Guard    Action             10.22
# 97  2025-09-20     Canada       Glass Onion    Action             14.90
# 98  2025-09-14         UK  The Adam Project     Drama             14.94
# 99  2025-09-30    Germany  The Adam Project   Romance              8.24
#
#     Watch Time (hours)  Revenue (USD millions) Subscriber Type
# ...

# %%
grouped_df = df.groupby('Movie Title').sum()
grouped_df
# Out:
#                                                                Date  \
# Movie Title
# Army of the Dead  2025-09-232025-09-082025-09-082025-09-102025-0...
# Bird Box          2025-09-282025-09-012025-09-302025-09-292025-0...
# Don't Look Up     2025-09-062025-09-122025-09-302025-09-132025-0...
# Enola Holmes 2    2025-09-072025-09-292025-09-132025-09-042025-0...
# Extraction 2      2025-09-292025-09-242025-09-192025-09-142025-0...
# Glass Onion                          2025-09-182025-09-152025-09-20
# Heart of Stone    2025-09-192025-09-182025-09-272025-09-292025-0...
# Project Power     2025-09-282025-09-022025-09-162025-09-092025-0...
# Red Notice        2025-09-302025-09-062025-09-032025-09-282025-0...
# Spaceman                             2025-09-192025-09-112025-09-20
# The Adam Project  2025-09-242025-09-232025-09-062025-09-232025-0...
# The Gray Man      2025-09-202025-09-072025-09-262025-09-042025-0...
# The Mother                           2025-09-232025-09-112025-09-30
# ...

# %%
agg_df = df.groupby('Movie Title').agg({'Views (millions)': 'mean'})
agg_df
# Out:
#                   Views (millions)
# Movie Title
# Army of the Dead          5.450000
# Bird Box                  5.963750
# Don't Look Up             3.680000
# Enola Holmes 2            9.003750
# Extraction 2             11.114000
# Glass Onion               9.130000
# Heart of Stone            5.995000
# Project Power             8.535714
# Red Notice                9.426667
# Spaceman                  4.203333
# The Adam Project          7.988750
# The Gray Man              7.592857
# The Mother                9.663333
# The Old Guard             8.285000
# Triple Frontier           6.457500

# %%
count_df = df.groupby('Movie Title').count()
count_df
# Out:
#                   Date  Region  Genre  Views (millions)  Watch Time (hours)  \
# Movie Title
# Army of the Dead     7       7      7                 7                   7
# Bird Box             8       8      8                 8                   8
# Don't Look Up        6       6      6                 6                   6
# Enola Holmes 2       8       8      8                 8                   8
# Extraction 2         5       5      5                 5                   5
# Glass Onion          3       3      3                 3                   3
# Heart of Stone       8       8      8                 8                   8
# Project Power        7       7      7                 7                   7
# Red Notice           9       9      9                 9                   9
# Spaceman             3       3      3                 3                   3
# The Adam Project     8       8      8                 8                   8
# ...

# %%
sum_df = df.groupby('Movie Title').sum()
sum_df
# Out:
#                                                                Date  \
# Movie Title
# Army of the Dead  2025-09-232025-09-082025-09-082025-09-102025-0...
# Bird Box          2025-09-282025-09-012025-09-302025-09-292025-0...
# Don't Look Up     2025-09-062025-09-122025-09-302025-09-132025-0...
# Enola Holmes 2    2025-09-072025-09-292025-09-132025-09-042025-0...
# Extraction 2      2025-09-292025-09-242025-09-192025-09-142025-0...
# Glass Onion                          2025-09-182025-09-152025-09-20
# Heart of Stone    2025-09-192025-09-182025-09-272025-09-292025-0...
# Project Power     2025-09-282025-09-022025-09-162025-09-092025-0...
# Red Notice        2025-09-302025-09-062025-09-032025-09-282025-0...
# Spaceman                             2025-09-192025-09-112025-09-20
# The Adam Project  2025-09-242025-09-232025-09-062025-09-232025-0...
# The Gray Man      2025-09-202025-09-072025-09-262025-09-042025-0...
# The Mother                           2025-09-232025-09-112025-09-30
# ...

# %%
max_df = df.groupby('Movie Title').max()
min_df = df.groupby('Movie Title').min()
max_df
min_df
# Out:
#                         Date     Region        Genre  Views (millions)  \
# Movie Title
# Army of the Dead  2025-09-03  Australia       Action              1.61
# Bird Box          2025-09-01  Australia       Action              1.24
# Don't Look Up     2025-09-06     Brazil       Comedy              0.60
# Enola Holmes 2    2025-09-04     Canada       Action              1.22
# Extraction 2      2025-09-14  Australia       Action              0.67
# Glass Onion       2025-09-15  Australia       Action              2.31
# Heart of Stone    2025-09-01  Australia       Action              2.13
# Project Power     2025-09-02  Australia       Comedy              5.91
# Red Notice        2025-09-03  Australia  Documentary              5.03
# Spaceman          2025-09-11  Australia       Comedy              1.32
# The Adam Project  2025-09-06     Canada       Comedy              3.99
# The Gray Man      2025-09-01  Australia       Action              0.79
# ...

# %%
df_cleaned = df.dropna()
df_cleaned
# Out:
#           Date     Region       Movie Title     Genre  Views (millions)  \
# 0   2025-09-06      India     Don't Look Up     Drama              1.88
# 1   2025-09-29  Australia      Extraction 2  Thriller             12.51
# 2   2025-09-28      India     Project Power     Drama             10.47
# 3   2025-09-24         UK  The Adam Project    Horror              7.35
# 4   2025-09-09  Australia     The Old Guard  Thriller              2.22
# ..         ...        ...               ...       ...               ...
# 95  2025-09-23  Australia     The Old Guard    Comedy              6.94
# 96  2025-09-04     Canada     The Old Guard    Action             10.22
# 97  2025-09-20     Canada       Glass Onion    Action             14.90
# 98  2025-09-14         UK  The Adam Project     Drama             14.94
# 99  2025-09-30    Germany  The Adam Project   Romance              8.24
#
#     Watch Time (hours)  Revenue (USD millions) Subscriber Type
# ...

# %%
df_filled = df.fillna(0)
df_filled
# Out:
#           Date     Region       Movie Title     Genre  Views (millions)  \
# 0   2025-09-06      India     Don't Look Up     Drama              1.88
# 1   2025-09-29  Australia      Extraction 2  Thriller             12.51
# 2   2025-09-28      India     Project Power     Drama             10.47
# 3   2025-09-24         UK  The Adam Project    Horror              7.35
# 4   2025-09-09  Australia     The Old Guard  Thriller              2.22
# ..         ...        ...               ...       ...               ...
# 95  2025-09-23  Australia     The Old Guard    Comedy              6.94
# 96  2025-09-04     Canada     The Old Guard    Action             10.22
# 97  2025-09-20     Canada       Glass Onion    Action             14.90
# 98  2025-09-14         UK  The Adam Project     Drama             14.94
# 99  2025-09-30    Germany  The Adam Project   Romance              8.24
#
#     Watch Time (hours)  Revenue (USD millions) Subscriber Type
# ...

# %%
df_replaced = df.replace({'NaN': 0})
df_replaced
# Out:
#           Date     Region       Movie Title     Genre  Views (millions)  \
# 0   2025-09-06      India     Don't Look Up     Drama              1.88
# 1   2025-09-29  Australia      Extraction 2  Thriller             12.51
# 2   2025-09-28      India     Project Power     Drama             10.47
# 3   2025-09-24         UK  The Adam Project    Horror              7.35
# 4   2025-09-09  Australia     The Old Guard  Thriller              2.22
# ..         ...        ...               ...       ...               ...
# 95  2025-09-23  Australia     The Old Guard    Comedy              6.94
# 96  2025-09-04     Canada     The Old Guard    Action             10.22
# 97  2025-09-20     Canada       Glass Onion    Action             14.90
# 98  2025-09-14         UK  The Adam Project     Drama             14.94
# 99  2025-09-30    Germany  The Adam Project   Romance              8.24
#
#     Watch Time (hours)  Revenue (USD millions) Subscriber Type
# ...

# %%
df['Contains_a'] = df['Movie Title'].str.contains('D')
df
# Out:
#           Date     Region       Movie Title     Genre  Views (millions)  \
# 0   2025-09-06      India     Don't Look Up     Drama              1.88
# 1   2025-09-29  Australia      Extraction 2  Thriller             12.51
# 2   2025-09-28      India     Project Power     Drama             10.47
# 3   2025-09-24         UK  The Adam Project    Horror              7.35
# 4   2025-09-09  Australia     The Old Guard  Thriller              2.22
# ..         ...        ...               ...       ...               ...
# 95  2025-09-23  Australia     The Old Guard    Comedy              6.94
# 96  2025-09-04     Canada     The Old Guard    Action             10.22
# 97  2025-09-20     Canada       Glass Onion    Action             14.90
# 98  2025-09-14         UK  The Adam Project     Drama             14.94
# 99  2025-09-30    Germany  The Adam Project   Romance              8.24
#
#     Watch Time (hours)  Revenue (USD millions) Subscriber Type  Contains_a  \
# ...

# %%
counts = df['Movie Title'].value_counts( )
counts
# Out:
# Movie Title
# The Old Guard       10
# Red Notice           9
# The Adam Project     8
# Bird Box             8
# Enola Holmes 2       8
# Triple Frontier      8
# Heart of Stone       8
# The Gray Man         7
# Project Power        7
# Army of the Dead     7
# Don't Look Up        6
# Extraction 2         5
# Glass Onion          3
# The Mother           3
# Spaceman             3
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
df.plot(x='Movie Title', y='Views (millions)', kind='line', marker='o',figsize=(20,10))
# Out:
# <Axes: xlabel='Movie Title'>

# %%
df.plot(x='Date', y='Revenue (USD millions)', kind='bar',
color='skyblue',figsize=(30,10))
# Out:
# <Axes: xlabel='Date'>

# %%
df['Revenue (USD millions)'].plot(kind='hist',color='green', edgecolor='black')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(x='Revenue (USD millions)', y='Date', kind='scatter', color='red')
# Out:
# <Axes: xlabel='Revenue (USD millions)', ylabel='Date'>

# %%
avg_revenue = df.groupby('Genre')['Revenue (USD millions)'].mean()
avg_revenue.plot(kind='bar', title='Average Revenue by Genre')
# Out:
# <Axes: title={'center': 'Average Revenue by Genre'}, xlabel='Genre'>

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.groupby('Date')['Views (millions)'].sum().plot(kind='line', title='Daily Netflix Views Trend')
# Out:
# <Axes: title={'center': 'Daily Netflix Views Trend'}, xlabel='Date'>

# %%
df.groupby('Subscriber Type')['Views (millions)'].mean().plot(kind='bar', title='Average Views by Subscriber Type')
# Out:
# <Axes: title={'center': 'Average Views by Subscriber Type'}, xlabel='Subscriber Type'>

# %%
#Which genre has the highest total views across all regions?
df.groupby('Genre')['Views (millions)'].sum().sort_values(ascending=False).head(1)
# Out:
# Genre
# Action    147.91
# Name: Views (millions), dtype: float64

# %%
#Find the correlation between views, watch time, and revenue.
df[['Views (millions)', 'Watch Time (hours)', 'Revenue (USD millions)']].corr()
# Out:
#                         Views (millions)  Watch Time (hours)  \
# Views (millions)                1.000000            0.904863
# Watch Time (hours)              0.904863            1.000000
# Revenue (USD millions)          0.908422            0.811425
#
#                         Revenue (USD millions)
# Views (millions)                      0.908422
# Watch Time (hours)                    0.811425
# Revenue (USD millions)                1.000000

# %%
#Identify the most profitable day (highest total revenue).
df['Date'] = pd.to_datetime(df['Date'])
df.groupby('Date')['Revenue (USD millions)'].sum().sort_values(ascending=False).head(1)
# Out:
# Date
# 2025-09-30    75.71
# Name: Revenue (USD millions), dtype: float64

# %%
#Create a scatter plot between Watch Time and Revenue.
plt.scatter(df['Watch Time (hours)'], df['Revenue (USD millions)'], alpha=0.7)
plt.title('Watch Time vs Revenue')
plt.xlabel('Watch Time (hours)')
plt.ylabel('Revenue (USD millions)')
plt.show()

# %%
#Determine which region has the most balanced genre performance (least variance in revenue).
df.groupby('Region')['Revenue (USD millions)'].var().sort_values().head(1)
# Out:
# Region
# Brazil    28.907364
# Name: Revenue (USD millions), dtype: float64

# %%
#Plot total Netflix views by region (bar graph).
df.groupby('Region')['Views (millions)'].sum().plot(kind='bar', color='skyblue')
plt.title('Total Netflix Views by Region')
plt.ylabel('Views (millions)')
plt.xlabel('Region')
plt.show()

# %%
#Pie chart showing percentage share of genres.
df['Genre'].value_counts().plot(kind='pie', autopct='%1.1f%%', startangle=90)
plt.title('Genre Distribution')
plt.ylabel('')
plt.show()

# %%
#Multi-bar chart: revenue per genre by subscriber type.
df.groupby(['Genre', 'Subscriber Type'])['Revenue (USD millions)'].mean().unstack().plot(kind='bar')
plt.title('Revenue per Genre by Subscriber Type')
plt.ylabel('Revenue (USD millions)')
plt.show()
